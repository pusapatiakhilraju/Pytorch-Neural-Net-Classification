# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import torch
# %matplotlib inline

# %%
scalar = torch.tensor(7)
vector = torch.tensor([[7,7]])
MATRIX = torch.tensor([[1,2],[3,4]])
TENSOR = torch.tensor([[[1,2],[3,4], [5,6]]])

# %% [markdown]
# # Random Tensors

# %%
random = torch.rand(5)

# %%
random
# Out:
# tensor([0.0670, 0.9809, 0.4865, 0.6507, 0.7064])
